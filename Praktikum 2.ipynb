# %%
from statistics import mean
#Fix Error
# panjang = 20.5
# lebar = 25
# tinggi = 10

# keliling = 2 * (panjang + lebar)
# luas = panjang * lebar
# volume = panjang * lebar * tinggi

# print("Panjang = " , panjang)
# print("Lebar = " , lebar)
# print("Tinggi = ", tinggi)
# print("Keliling = ", keliling)
# print("Volume = ", volume)

#Menghitung nilai rata-rata Shafira
# shafira = [85, 75]
# r_shafira = mean(shafira)

# print(r_shafira)

#Jumlah nilai Hanif dan Andi di semua mata kuliah
# hanif = 75 + 90
# andi = 70 + 75

# print("Jumlah nilai Hanif dan Andi adalah\n")
# print(hanif + andi)

#
# kal_1 = [85, 85, 80, 95]
# met_sta = [85, 85, 75, 80]
# r_kal1 = mean(kal_1)
# r_metsta = mean(met_sta)



# print("Rata-rata nilai Widya, Dhanar, Hikma, dan Nedia pada mata kuliah Kalkulus 1 adalah" , r_kal1)
# print("Rata-rata nilai Widya, Dhanar, Hikma, dan Nedia pada mata kuliah Metode Statistika adalah" , r_metsta)

#Menentukan nilai rata-rata pada mata kuliah Kalkulus 1
# kal_1 = [85, 80, 75, 95, 85, 75, 70, 85, 80]
# r_kal1 = mean(kal_1)

# print("Rata-rata nilai mata kuliah Kalkulus 1 adalah", r_kal1)

#Menentukan nilai rata-rata pada mata kuliah Metode Statistika
# met_sta = [75, 90, 80, 80, 85, 90, 75, 85, 75]
# r_metsta = mean(met_sta)

# print("Rata-rata nilai mata kuliah Metode Statistika adalah", r_metsta)

# #soal pertama
# gaji_jam = 30000
# gaji_hari = gaji_jam * 8
# #Gaji bulan agustus jika tidak masuk kerja 3 hari
# gaji_bulan = gaji_hari * 20


# print("Gaji Dwi bulan Agustus jika tidak masuk selama 3 hari adalah", gaji_bulan)

#soal kedua
# gaji_jam = 30000
# gaji_hari = gaji_jam * 8
# #Gaji bulan agustus jika tidak masuk kerja 3 hari
# gaji_bulan = gaji_hari * 20
# tunjangan = gaji_bulan * (10 / 100)
# print("Tunjangan yang diterima Dwi dibulan Agustus sebesar", int(tunjangan))


#soal ketiga
gaji_jam = 30000
upah_lembur = 10000 * 5
gaji_hari = gaji_jam * 8
#Gaji bulan agustus jika tidak masuk kerja 3 hari
gaji_bulan = gaji_hari * 20
tunjangan = gaji_bulan * (10 / 100)
total_gaji = gaji_bulan + tunjangan + upah_lembur
print("Total gaji yang diterima Dwi dibulan Agustus sebesar", int(total_gaji))
# Out:
# Total gaji yang diterima Dwi dibulan Agustus sebesar 5330000
